# %% [markdown]
# ## MERGing

# %% [markdown]
# ### Sample DataFrames

# %%
import pandas as pd
employees = pd.DataFrame({
    "EmpID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "DeptID": [10, 20, 30]
})

departments = pd.DataFrame({
    "DeptID": [10, 20, 40],
    "DeptName": ["HR", "Engineering", "Marketing"]
})
employees
# Out:
#    EmpID     Name  DeptID
# 0      1    Alice      10
# 1      2      Bob      20
# 2      3  Charlie      30

# %%
departments
# Out:
#    DeptID     DeptName
# 0      10           HR
# 1      20  Engineering
# 2      40    Marketing

# %% [markdown]
# #### MERGE/ INNER JOIN

# %%
pd.merge(employees , departments, on = "DeptID")
# Out:
#    EmpID   Name  DeptID     DeptName
# 0      1  Alice      10           HR
# 1      2    Bob      20  Engineering

# %% [markdown]
# #### LEFT Inner Join

# %%
pd.merge(employees, departments, on = "DeptID", how = "left")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0      1    Alice      10           HR
# 1      2      Bob      20  Engineering
# 2      3  Charlie      30          NaN

# %% [markdown]
# #### RIGHT Inner Join

# %%
pd.merge(employees, departments, on = "DeptID", how = "right")
# Out:
#    EmpID   Name  DeptID     DeptName
# 0    1.0  Alice      10           HR
# 1    2.0    Bob      20  Engineering
# 2    NaN    NaN      40    Marketing

# %% [markdown]
# #### OUTER Join

# %%
pd.merge(employees, departments, on = "DeptID", how = "outer")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10           HR
# 1    2.0      Bob      20  Engineering
# 2    3.0  Charlie      30          NaN
# 3    NaN      NaN      40    Marketing

# %% [markdown]
# ## CONCAT

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"]})

df1
# Out:
#     Name
# 0  Alice
# 1    Bob

# %%
df2
# Out:
#       Name
# 0  Charlie
# 1    David

# %%
pd.concat([df1, df2])
# Out:
#       Name
# 0    Alice
# 1      Bob
# 0  Charlie
# 1    David

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#     Name     Name
# 0  Alice  Charlie
# 1    Bob    David

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"], "Score":[45,51]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"], "ID":[1,5]})

df1
# Out:
#     Name  Score
# 0  Alice     45
# 1    Bob     51

# %%
df2
# Out:
#       Name  ID
# 0  Charlie   1
# 1    David   5

# %%
pd.concat([df1, df2])
# Out:
#       Name  Score   ID
# 0    Alice   45.0  NaN
# 1      Bob   51.0  NaN
# 0  Charlie    NaN  1.0
# 1    David    NaN  5.0

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#     Name  Score     Name  ID
# 0  Alice     45  Charlie   1
# 1    Bob     51    David   5
